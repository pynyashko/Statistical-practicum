# %% [markdown]
# ### Problem 1

# %%
new_tuple = tuple(x for x in range(1, int(12345**0.5) + 1) if (x**2 % 12 == 0 and x**2 % 8 != 0))
print(new_tuple)
# Out:
# (6, 18, 30, 42, 54, 66, 78, 90, 102)

# %% [markdown]
# ### Problem 2

# %%
m = [
    [1,2,3],
    [4,5,6],
    [7,8,9]
]
# print(list(zip(*m[::-1])), end="\n")
# print(list(zip(*m))[::-1])
# print([list(row) for row in zip(*m[::-1])])
# print([list(row) for row in zip(*m)][::-1])



def rotate(matrix, side):
    rows = len(matrix)
    cols = len(matrix[0])
    matrix_is_appropriate = (rows == cols)
    if side == "left" and matrix_is_appropriate:
        turned_left_matrix = [list(row) for row in zip(*matrix)][::-1]
        return turned_left_matrix
    elif side == "right" and matrix_is_appropriate:
        turned_right_matrix = [list(row) for row in zip(*matrix[::-1])]
        return turned_right_matrix
    else:
        print("Неправильно набран номер")
        return -1

rotated_matrix = rotate(m, "right")
print(rotated_matrix)
# Out:
# [[7, 4, 1], [8, 5, 2], [9, 6, 3]]

# %% [markdown]
# ### Problem 3

# %%
count_letters = lambda word: {letter: word.count(letter) for letter in word}
print(count_letters("hello, world!"))
# Out:
# {'h': 1, 'e': 1, 'l': 3, 'o': 2, ',': 1, ' ': 1, 'w': 1, 'r': 1, 'd': 1, '!': 1}

# %% [markdown]
# ### Problem 4

# %%
class Library:
    def __init__(self, history):
        self.books = []
        self.users = []
        self.transaction_history = []

    def add_book(self, book):
        self.books.append(book)

    def remove_book(self, book):
        if book in self.books:
            self.books.remove(book)
            return True
        return False
    
    def register_student(self, user):
        self.users.append(user)
        return True

    def deregister_student(self, user):
        if user in self.users:
            self.users.remove(user)
            return True
        return False

    def display_transaction_history(self):
        for record in self.transaction_history:
            print(record);

class Book:
    def __init__(self, title, author, year_of_publication, isbn, number_of_copies):
        self.title = title
        self.author = author
        self.year_of_publication = year_of_publication
        self.isbn = isbn
        self.number_of_copies = number_of_copies
        print(f"Book {name} created")

    def copies_amount(self):
        return self.number_of_copies
    
    def ():
        ...

    def 


class User:
    def __init__(self, username, lib_card):
        self.username = username
        self.lib_card = libcard
        self.borrowed_books = []
        print(f"User {name} created")

    def take_book(self, book):
        if bool(book.number_of_copies()):
            self.borrowed_books.append(book)
            return True
        return False

    def give_book_back(self, book):
        self.borrowed_books.remove(book)
        return
# Out:
#   Cell In[38], line 23
#     class Book:
#                ^
# IndentationError: expected an indented block after 'if' statement on line 21

# %% [markdown]
# ### Problem 5
# Beacuse python's veriables point to object's address, not to objects themselves. So when we assign variable a address to variable b, but not copy it.

# %% [markdown]
# ### Problem 6

# %%
A, B = 0, 0
for i in range(1,10001):
    A = A + 1/i**2

for i in range(10000, 0, -1):
    B = B + 1/i**2

print(A, B)
# Out:
# 1.6448340718480652 1.6448340718480596

# %% [markdown]
# We observe, that final values are different. That is because of different terms' orders. When we summarize small and big values, error seems unnoticable for computer.
